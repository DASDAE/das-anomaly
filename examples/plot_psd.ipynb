# %%
from das_anomaly.psd import PSDConfig, PSDGenerator
from das_anomaly.utils import plot_spec

# %% [markdown]
# An example anomaly

# %%
# define the data path for plotting
data_path = "/path/to/DAS/data/" 

# define start and end time
t1 = '2022-12-06 20:03:52'
t2 = '2022-12-06 20:03:54' 

cfg = PSDConfig(data_path=data_path, t1=t1, t2=t2, hide_axes=False, save_fig=False)

# %%
PSDGenerator(cfg).run()

# %% [markdown]
# background noise example

# %%
# define the data path for plotting
data_path = "/path/to/DAS/data/" 

# define start and end time
t1 = '2023-01-25 17:00:44'
t2 = '2023-01-25 17:00:46' 

cfg = PSDConfig(data_path=data_path, t1=t1, t2=t2, hide_axes=False, save_fig=False)

# %%
PSDGenerator(cfg).run()
